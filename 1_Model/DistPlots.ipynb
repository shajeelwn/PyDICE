# %%
from scipy import stats
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
# t = np.linspace(-5,8, 2000)
# plt.figure(figsize=(10,5))
# plt.plot(t,stats.norm.pdf(t, 1, 0.44), label = 'Normal')
# plt.plot(t,stats.lognorm.pdf(t, .5, 0, 1), label = 'Log-Normal')
# plt.plot(t,stats.cauchy.pdf(t, 0, .35), label ='Cauchy')
# #plt.plot(t,stats.levy.pdf(t,  0, 0.5), label = 'Lévy')
# plt.plot(t,stats.exponweib.pdf(t, 1.89, 1, 0, 0.565), label = 'Weibull')
# plt.plot(t,stats.pareto.pdf(t, 0.5, -0.5, 0.55), color = sns.cubehelix_palette(10)[9],  label = 'Pareto')
# plt.legend()

# %%
with open('ecs_dist_v4.json') as f:
    d=json.load(f)

t = np.linspace(-5,15, 2000)
plt.figure(figsize=(10,5))
plt.plot(t,stats.norm.pdf(t, d['norm'][0],d['norm'][1]), color = sns.color_palette("inferno", 15)[-3], label = 'Normal')
plt.plot(t,stats.lognorm.pdf(t, d['lognorm'][0],d['lognorm'][1],d['lognorm'][2]), color =sns.color_palette("viridis", 10)[-4], label = 'Log-Normal')
plt.plot(t,stats.cauchy.pdf(t, d['cauchy'][0],d['cauchy'][1]), color = sns.cubehelix_palette(10)[5], label = 'Cauchy')
plt.legend()

# %%
with open('ecs_dist_v4.json') as f:
    d=json.load(f)

t = np.linspace(-5,15, 2000)
plt.figure(figsize=(10,5))
plt.plot(t,stats.norm.pdf(t, d['norm'][0],d['norm'][1]), color = sns.color_palette("inferno", 15)[-3], label = 'Normal')
plt.plot(t,stats.lognorm.pdf(t, d['lognorm'][0],d['lognorm'][1],d['lognorm'][2]), color =sns.color_palette("viridis", 10)[-4], label = 'Log-Normal')
plt.plot(t,stats.cauchy.pdf(t, d['cauchy'][0],d['cauchy'][1]), color = sns.cubehelix_palette(10)[5], label = 'Cauchy')
plt.legend()
plt.xlim(6,15)
plt.ylim(0,0.1)
# Out:
# (0, 0.1)
